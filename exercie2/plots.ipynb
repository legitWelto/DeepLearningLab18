# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# filter 3
print("lr=0.1    validation error " + str(0.0138))
print("lr=0.01   validation error " + str(0.0351))
print("lr=0.001  validation error " + str(0.0831))
print("lr=0.0001 validation error " + str(0.7152))

lr1 = [0.0431, 0.0271, 0.0193, 0.018, 0.0186, 0.0157, 0.0129, 0.0147, 0.0152, 0.0157]
lr2 = [0.081, 0.0709, 0.0622, 0.046, 0.0459, 0.0391, 0.0358, 0.0346, 0.033, 0.0329]
lr3 = [0.5305, 0.267, 0.1584, 0.121, 0.1051, 0.097, 0.0915, 0.0845, 0.081, 0.0768]
lr4 = [0.8494, 0.8243, 0.8034, 0.7882, 0.779, 0.7668, 0.758, 0.7464, 0.735, 0.7202]

fig, (ax) = plt.subplots(1, 1, figsize=(18,12))
ax.set_xlim([0, 9])
ax.set_xlabel('epoch')
ax.set_ylabel('error')
ax.plot(lr1, c='b', label='learningrate 0.1')
ax.plot(lr2, c='r', label='learningrate 0.01')
ax.plot(lr3, c='y', label='learningrate 0.001')
ax.plot(lr4, c='g', label='learningrate 0.0001')
ax.legend(loc='upper right')
       
fig.canvas.draw()
# Out:
# lr=0.1    validation error 0.0138
# lr=0.01   validation error 0.0351
# lr=0.001  validation error 0.0831
# lr=0.0001 validation error 0.7152

# %%
# filter 1
print("lr=0.1    validation error " + str(0.0295))
print("lr=0.01   validation error " + str(0.0539))
print("lr=0.001  validation error " + str(0.1211))
print("lr=0.0001 validation error " + str(0.8432))

lr1 = [0.063, 0.0501, 0.038, 0.0395, 0.0318, 0.0308, 0.0332, 0.0309, 0.0371, 0.0309]
lr2 = [0.1396, 0.0908, 0.0829, 0.0792, 0.0701, 0.0661, 0.06, 0.0596, 0.0539, 0.0516]
lr3 = [0.6731, 0.3963, 0.2789, 0.2235, 0.1902, 0.1605, 0.1448, 0.1351, 0.1252, 0.1165]
lr4 = [0.8882, 0.8853, 0.8806, 0.8774, 0.8729, 0.8672, 0.8614, 0.8558, 0.8466, 0.8381]

fig, (ax) = plt.subplots(1, 1, figsize=(18,12))
ax.set_xlim([0, 9])
ax.set_xlabel('epoch')
ax.set_ylabel('error')
ax.plot(lr1, c='b', label='learningrate 0.1')
ax.plot(lr2, c='r', label='learningrate 0.01')
ax.plot(lr3, c='y', label='learningrate 0.001')
ax.plot(lr4, c='g', label='learningrate 0.0001')
ax.legend(loc='upper right')
       
fig.canvas.draw()
# Out:
# lr=0.1    validation error 0.0295
# lr=0.01   validation error 0.0539
# lr=0.001  validation error 0.1211
# lr=0.0001 validation error 0.8432

# %%
# filter 5
print("lr=0.1    validation error " + str(0.0126))
print("lr=0.01   validation error " + str(0.0232))
print("lr=0.001  validation error " + str(0.0817))
print("lr=0.0001 validation error " + str(0.6974))

lr1 = [0.0266, 0.0224, 0.0164, 0.0151, 0.0126, 0.0121, 0.0159, 0.0149, 0.0133, 0.0121]
lr2 = [0.0915, 0.1357, 0.0474, 0.0548, 0.0363, 0.0355, 0.032, 0.0326, 0.0276, 0.0239]
lr3 = [0.6505, 0.4678, 0.1901, 0.129, 0.1078, 0.0976, 0.0913, 0.0867, 0.0834, 0.0789]
lr4 = [0.9163, 0.8957, 0.8715, 0.85, 0.8282, 0.8057, 0.7782, 0.7472, 0.7158, 0.6817]

fig, (ax) = plt.subplots(1, 1, figsize=(18,12))
ax.set_xlim([0, 9])
ax.set_xlabel('epoch')
ax.set_ylabel('error')
ax.plot(lr1, c='b', label='learningrate 0.1')
ax.plot(lr2, c='r', label='learningrate 0.01')
ax.plot(lr3, c='y', label='learningrate 0.001')
ax.plot(lr4, c='g', label='learningrate 0.0001')
ax.legend(loc='upper right')
       
fig.canvas.draw()
# Out:
# lr=0.1    validation error 0.0126
# lr=0.01   validation error 0.0232
# lr=0.001  validation error 0.0817
# lr=0.0001 validation error 0.6974

# %%
# filter 7
print("lr=0.1    validation error " + str(0.0121))
print("lr=0.01   validation error " + str(0.0249))
print("lr=0.001  validation error " + str(0.0738))
print("lr=0.0001 validation error " + str(0.6276))

lr1 = [0.0275, 0.0203, 0.0164, 0.016, 0.0152, 0.0181, 0.0122, 0.0125, 0.0117, 0.0116]
lr2 =  [0.084, 0.0567, 0.0461, 0.0388, 0.0335, 0.0265, 0.0295, 0.0241, 0.0253, 0.0236]
lr3 = [0.7522, 0.2714, 0.1539, 0.1174, 0.1071, 0.0953, 0.0871, 0.08, 0.0794, 0.0731]
lr4 = [0.9134, 0.8911, 0.865, 0.8354, 0.8035, 0.7756, 0.7399, 0.7021, 0.6606, 0.614]
fig, (ax) = plt.subplots(1, 1, figsize=(18,12))
ax.set_xlim([0, 9])
ax.set_xlabel('epoch')
ax.set_ylabel('error')
ax.plot(lr1, c='b', label='learningrate 0.1')
ax.plot(lr2, c='r', label='learningrate 0.01')
ax.plot(lr3, c='y', label='learningrate 0.001')
ax.plot(lr4, c='g', label='learningrate 0.0001')
ax.legend(loc='upper right')
       
fig.canvas.draw()
# Out:
# lr=0.1    validation error 0.0121
# lr=0.01   validation error 0.0249
# lr=0.001  validation error 0.0738
# lr=0.0001 validation error 0.6276

# %%
# lr=0.1
print("filter_size 1    validation error " + str(0.0295))
print("filter_size 3    validation error " + str(0.0138))
print("filter_size 5    validation error " + str(0.0126))
print("filter_size 7    validation error " + str(0.0121))

fl1 = [0.063, 0.0501, 0.038, 0.0395, 0.0318, 0.0308, 0.0332, 0.0309, 0.0371, 0.0309]
fl3 = [0.0431, 0.0271, 0.0193, 0.018, 0.0186, 0.0157, 0.0129, 0.0147, 0.0152, 0.0157]
fl5 = [0.0266, 0.0224, 0.0164, 0.0151, 0.0126, 0.0121, 0.0159, 0.0149, 0.0133, 0.0121]
fl7 = [0.0275, 0.0203, 0.0164, 0.016, 0.0152, 0.0181, 0.0122, 0.0125, 0.0117, 0.0116]


fig, (ax) = plt.subplots(1, 1, figsize=(18,12))
ax.set_xlim([0, 9])
ax.set_xlabel('epoch')
ax.set_ylabel('error')
ax.plot(fl1, c='g', label='filter_size 1')
ax.plot(fl3, c='b', label='filter_size 3')
ax.plot(fl5, c='r', label='filter_size 5')
ax.plot(fl7, c='y', label='filter_size 7')
ax.legend(loc='upper right')
       
fig.canvas.draw()
# Out:
# filter_size 1    validation error 0.0295
# filter_size 3    validation error 0.0138
# filter_size 5    validation error 0.0126
# filter_size 7    validation error 0.0121

# %%
# lr=0.01
print("filter_size 1    validation error " + str(0.0539))
print("filter_size 3    validation error " + str(0.0351))
print("filter_size 5    validation error " + str(0.0232))
print("filter_size 7    validation error " + str(0.0249))

fl1 = [0.1396, 0.0908, 0.0829, 0.0792, 0.0701, 0.0661, 0.06, 0.0596, 0.0539, 0.0516]
fl3 = [0.081, 0.0709, 0.0622, 0.046, 0.0459, 0.0391, 0.0358, 0.0346, 0.033, 0.0329]
fl5 = [0.0915, 0.1357, 0.0474, 0.0548, 0.0363, 0.0355, 0.032, 0.0326, 0.0276, 0.0239]
fl7 = [0.084, 0.0567, 0.0461, 0.0388, 0.0335, 0.0265, 0.0295, 0.0241, 0.0253, 0.0236]


fig, (ax) = plt.subplots(1, 1, figsize=(18,12))
ax.set_xlim([0, 9])
ax.set_xlabel('epoch')
ax.set_ylabel('error')
ax.plot(fl1, c='g', label='filter_size 1')
ax.plot(fl3, c='b', label='filter_size 3')
ax.plot(fl5, c='r', label='filter_size 5')
ax.plot(fl7, c='y', label='filter_size 7')
ax.legend(loc='upper right')
       
fig.canvas.draw()
# Out:
# filter_size 1    validation error 0.0539
# filter_size 3    validation error 0.0351
# filter_size 5    validation error 0.0232
# filter_size 7    validation error 0.0249

# %%
# lr=0.001
print("filter_size 1    validation error " + str(0.1211))
print("filter_size 3    validation error " + str(0.0831))
print("filter_size 5    validation error " + str(0.0817))
print("filter_size 7    validation error " + str(0.0738))

fl1 = [0.6731, 0.3963, 0.2789, 0.2235, 0.1902, 0.1605, 0.1448, 0.1351, 0.1252, 0.1165]
fl3 = [0.5305, 0.267, 0.1584, 0.121, 0.1051, 0.097, 0.0915, 0.0845, 0.081, 0.0768]
fl5 = [0.6505, 0.4678, 0.1901, 0.129, 0.1078, 0.0976, 0.0913, 0.0867, 0.0834, 0.0789]
fl7 = [0.7522, 0.2714, 0.1539, 0.1174, 0.1071, 0.0953, 0.0871, 0.08, 0.0794, 0.0731]


fig, (ax) = plt.subplots(1, 1, figsize=(18,12))
ax.set_xlim([0, 9])
ax.set_xlabel('epoch')
ax.set_ylabel('error')
ax.plot(fl1, c='g', label='filter_size 1')
ax.plot(fl3, c='b', label='filter_size 3')
ax.plot(fl5, c='r', label='filter_size 5')
ax.plot(fl7, c='y', label='filter_size 7')
ax.legend(loc='upper right')
       
fig.canvas.draw()
# Out:
# filter_size 1    validation error 0.1211
# filter_size 3    validation error 0.0831
# filter_size 5    validation error 0.0817
# filter_size 7    validation error 0.0738

# %%
# lr=0.001
print("filter_size 1    validation error " + str(0.8432))
print("filter_size 3    validation error " + str(0.7152))
print("filter_size 5    validation error " + str(0.6974))
print("filter_size 7    validation error " + str(0.6276))

fl1 = [0.8882, 0.8853, 0.8806, 0.8774, 0.8729, 0.8672, 0.8614, 0.8558, 0.8466, 0.8381]
fl3 = [0.8494, 0.8243, 0.8034, 0.7882, 0.779, 0.7668, 0.758, 0.7464, 0.735, 0.7202]
fl5 = [0.9163, 0.8957, 0.8715, 0.85, 0.8282, 0.8057, 0.7782, 0.7472, 0.7158, 0.6817]
fl7 = [0.9134, 0.8911, 0.865, 0.8354, 0.8035, 0.7756, 0.7399, 0.7021, 0.6606, 0.614]


fig, (ax) = plt.subplots(1, 1, figsize=(18,12))
ax.set_xlim([0, 9])
ax.set_xlabel('epoch')
ax.set_ylabel('error')
ax.plot(fl1, c='g', label='filter_size 1')
ax.plot(fl3, c='b', label='filter_size 3')
ax.plot(fl5, c='r', label='filter_size 5')
ax.plot(fl7, c='y', label='filter_size 7')
ax.legend(loc='upper right')
       
fig.canvas.draw()
# Out:
# filter_size 1    validation error 0.8432
# filter_size 3    validation error 0.7152
# filter_size 5    validation error 0.6974
# filter_size 7    validation error 0.6276
